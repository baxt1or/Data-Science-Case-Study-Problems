# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./dataset/credit_loan.csv")

df.head()
# Out:
#    customer_id  age    education employment_type  income  credit_history  \
# 0            1   39  High School      Unemployed   74829               0
# 1            2   61  High School      Unemployed   35085               1
# 2            3   53     Bachelor   Self-Employed  150700               1
# 3            4   23     Bachelor        Salaried   83249               1
# 4            5   24  High School   Self-Employed  100003               1
#
#    gender marital_status                                            address  \
# 0  Female       Divorced  8127 Richard Way Apt. 064\nCrawfordchester, NY...
# 1    Male         Single     704 Austin Key Suite 445\nMoorehaven, HI 55539
# 2    Male       Divorced    96584 Jeffrey View\nPort Richardhaven, AR 38648
# 3  Female       Divorced   426 Alice Camp Suite 836\nLake Maxwell, VT 24197
# 4    Male        Married    087 Black Summit Suite 507\nJanetport, AS 44182
#
# ...
